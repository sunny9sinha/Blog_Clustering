# %% [markdown]
# <a href="https://colab.research.google.com/github/sunny9sinha/Blog_Clustering/blob/main/Grid_Based_Clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
import numpy as np

iris = load_iris()
X = iris.data[:, :2] # Use the first two features for clustering

# %%
from sklearn.preprocessing import StandardScaler

# Scaling Data
scaler = StandardScaler()
scaler.fit(X)
X = scaler.transform(X)

# %%
grid_size = 0.5

# %%
x_min, x_max = np.min(X[:, 0]), np.max(X[:, 0])
y_min, y_max = np.min(X[:, 1]), np.max(X[:, 1])

x_range = np.arange(x_min, x_max, grid_size)
y_range = np.arange(y_min, y_max, grid_size)

xx, yy = np.meshgrid(x_range, y_range)
grid = np.c_[xx.ravel(), yy.ravel()]

# %%
from sklearn.neighbors import NearestNeighbors

nbrs = NearestNeighbors(n_neighbors=1).fit(grid)
distances, indices = nbrs.kneighbors(X)

# %%
import matplotlib.pyplot as plt

plt.scatter(X[:, 0], X[:, 1], s=50, c=indices)
plt.title('Grid-based Clustering')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.show()
